# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep7348/Assignment/blob/master/AglometricClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt1
import pandas as pd
from sklearn.cluster import AgglomerativeClustering

df = pd.read_csv("agglomerative_clustering_with_labels.csv")
data = df[["feature1", "feature2"]].head(20)
print(data)

# -------------------- Dendrogram --------------------
plt.figure(figsize=(10, 6))
plt.title("Hierarchy Clustering")

dendogram = shc.dendrogram(shc.linkage(data, method='ward'))
plt.show()     # <-- show AFTER plotting dendrogram

# -------------------- Agglomerative clustering --------------------
dataTest = AgglomerativeClustering(n_clusters=2, metric="euclidean", linkage="ward")
finalData = dataTest.fit(data)

# -------------------- Scatter plot --------------------
plt1.figure(figsize=(8, 5))
plt1.scatter(data.iloc[:, 0], data.iloc[:, 1],
             c=finalData.labels_, cmap='viridis', marker='o')

plt1.title("Agglomerative Clustering")
plt1.xlabel("Feature 1")
plt1.ylabel("Feature 2")
plt1.show()
# Out:
#     feature1  feature2
# 0   2.198686  1.944694
# 1   2.259075  2.609212
# 2   1.906339  1.906345
# 3   2.631685  2.306974
# 4   1.812210  2.217024
# 5   1.814633  1.813708
# 6   2.096785  1.234688
# 7   1.310033  1.775085
# 8   1.594868  2.125699
# 9   1.636790  1.435079
# 10  2.586260  1.909689
# 11  2.027011  1.430101
# 12  1.782247  2.044369
# 13  1.539603  2.150279
# 14  1.759745  1.883323
# 15  1.759317  2.740911
# 16  1.994601  1.576916
# 17  2.329018  1.511663
# 18  2.083545  1.216132
# 19  1.468726  2.078744
