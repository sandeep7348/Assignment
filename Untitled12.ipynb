# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep7348/Assignment/blob/master/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

X,_=make_circles(n_samples=40,factor=0.5,random_state=4,noise=.03)
dbscan=DBSCAN(eps=0.3,min_samples=2)
clusters=dbscan.fit(X)
print(clusters.labels_)

plt.scatter(X[:,0],X[:,1],c=clusters.labels_,cmap='viridis',marker='o')
plt.title("DB SCAN Algorithm")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()
# Out:
# [ 0  0  1  2  0  0  0  3  2 -1  4  0 -1  4  0  5 -1  0  0  0 -1  0  0  5
#   6  0  0  3  0  0  0  0  4  1  0 -1 -1  0  6 -1]
