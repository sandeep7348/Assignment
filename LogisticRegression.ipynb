# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep7348/Assignment/blob/master/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt


X, Y = make_classification(
    n_samples=100,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    class_sep=10
)


x_train, x_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)


model = LogisticRegression(max_iter=100)
modelTrain = model.fit(x_train, y_train)
y_pred = modelTrain.predict(x_test)

plt.figure(figsize=(10,6))
plt.title("Logistic Regression Classification")
plt.scatter(X[:,0], X[:,1], c=Y, cmap="viridis")


print("Accuracy:", accuracy_score(y_test, y_pred))
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")

plt.show()
# Out:
# Accuracy: 1.0
